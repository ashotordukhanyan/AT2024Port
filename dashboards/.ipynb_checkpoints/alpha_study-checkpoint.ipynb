# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

module_path = os.path.abspath('..',)
if module_path not in sys.path:
    print(f'Adding {module_path} to PYTHONPATH')
    sys.path.insert(0, module_path)
# Out:
# Adding C:\Users\orduk\PycharmProjects\AT2024Port to PYTHONPATH

# %%
from research.alpha_study import get_alpha_stats,qcutStats,csv_download_link
import perspective
import pandas as pd
import numpy as np
import seaborn as sns
from typing import List

# %%
alpha_stats_raw = get_alpha_stats(meanAdjust = True)
alpha_stats = alpha_stats_raw.dropna()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 345/345 [03:51<00:00,  1.49it/s]

# %%
RETURN_COLS = ['Return_1bd', 'Return_2bd', 'Return_3bd', 'Return_4bd',
        'Return_1wk', 'Return_2wk', 'Return_3wk', 'Return_4wk']

# %%
alpha_stats[['Alpha']+RETURN_COLS].corr()
# Out:
#                Alpha  Return_1bd  Return_2bd  Return_3bd  Return_4bd  \
# Alpha       1.000000    0.004988    0.005231    0.003567    0.002633
# Return_1bd  0.004988    1.000000    0.613869    0.559608    0.515495
# Return_2bd  0.005231    0.613869    1.000000    0.861634    0.776399
# Return_3bd  0.003567    0.559608    0.861634    1.000000    0.895959
# Return_4bd  0.002633    0.515495    0.776399    0.895959    1.000000
# Return_1wk -0.000060    0.465935    0.689583    0.813047    0.907246
# Return_2wk  0.001481    0.353391    0.526015    0.604298    0.659949
# Return_3wk  0.001951    0.308131    0.430733    0.492126    0.561982
# Return_4wk  0.001546    0.247823    0.369999    0.428265    0.489270
#
#             Return_1wk  Return_2wk  Return_3wk  Return_4wk
# Alpha        -0.000060    0.001481    0.001951    0.001546
# Return_1bd    0.465935    0.353391    0.308131    0.247823
# Return_2bd    0.689583    0.526015    0.430733    0.369999
# Return_3bd    0.813047    0.604298    0.492126    0.428265
# Return_4bd    0.907246    0.659949    0.561982    0.489270
# Return_1wk    1.000000    0.701665    0.590454    0.517176
# Return_2wk    0.701665    1.000000    0.815169    0.710396
# Return_3wk    0.590454    0.815169    1.000000    0.862432
# Return_4wk    0.517176    0.710396    0.862432    1.000000

# %%
corr_by_period = alpha_stats.groupby('ForecastDate').apply(\
    lambda g: g[['Alpha']+RETURN_COLS].corr()['Alpha'],include_groups=False)
corr_by_period[RETURN_COLS].plot()
# Out:
# <Axes: xlabel='ForecastDate'>

# %%
alpha_stats.ForecastDate = pd.to_datetime(alpha_stats.ForecastDate)
# Out:
# C:\Users\orduk\AppData\Local\Temp\ipykernel_29852\3293925158.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alpha_stats.ForecastDate = pd.to_datetime(alpha_stats.ForecastDate)

# %%
from scipy.stats import linregress
#The below shows that there is no strong statistical relationship between alpha forecasts and returns at any horizon
regRegresults = [ linregress(alpha_stats[R], alpha_stats.Alpha ) for R in RETURN_COLS ]
pd.DataFrame( index = RETURN_COLS, columns=['slope','intercept','rvalue','pvalue','stderr'],
    data=[ [r.slope,r.intercept,r.rvalue, r.pvalue, r.stderr ] for r in [ linregress(alpha_stats[R], alpha_stats.Alpha ) for R in RETURN_COLS ] ])
# Out:
#                slope  intercept    rvalue    pvalue    stderr
# Return_1bd  0.006261   0.109638  0.004988  0.045128  0.003125
# Return_2bd  0.004058   0.109259  0.005231  0.035642  0.001931
# Return_3bd  0.002323   0.109499  0.003567  0.151938  0.001621
# Return_4bd  0.001555   0.109405  0.002633  0.290244  0.001470
# Return_1wk -0.000032   0.109879 -0.000060  0.980766  0.001312
# Return_2wk  0.000570   0.109577  0.001481  0.551983  0.000959
# Return_3wk  0.000613   0.109398  0.001951  0.433184  0.000782
# Return_4wk  0.000420   0.109438  0.001546  0.534599  0.000676

# %%
#This shows no evidence that analyst alpha is strong in any particular sector either.
sectors = alpha_stats.PrimFactorCode.unique().tolist()
data=[ [r.slope,r.intercept,r.rvalue, r.pvalue, r.stderr ] for r in \
       [ linregress(alpha_stats[alpha_stats.PrimFactorCode==s].Return_1bd, alpha_stats[alpha_stats.PrimFactorCode==s].Alpha ) for s in sectors ] ] 

pd.DataFrame(index=sectors,data=data,columns = ['slope','intercept','rvalue','pvalue','stderr'])
# Out:
#          slope  intercept    rvalue    pvalue    stderr
# USIS  0.008981   0.718637  0.008242  0.437306  0.011562
# USHE  0.020094  -0.101373  0.016357  0.059458  0.010660
# USHT  0.008533   0.261032  0.008381  0.401341  0.010168
# USCM  0.024644   1.075604  0.019153  0.103712  0.015144
# USBK  0.034341   1.227305  0.031052  0.023170  0.015120
# USMT -0.003617   0.681865 -0.003705  0.728832  0.010432
# USIT -0.008306  -0.900348 -0.006427  0.383299  0.009527
# USTR -0.003146  -0.038723 -0.002645  0.863390  0.018282
# USRE -0.012968   0.439374 -0.014007  0.142311  0.008838
# USBT -0.000143  -1.742526 -0.000081  0.995541  0.025580
# USUT  0.020955   0.429480  0.019297  0.035148  0.009946
# USDF  0.038152   2.568983  0.022173  0.344580  0.040355
# USEE  0.020368   0.122842  0.016489  0.071069  0.011283
# USID  0.018283   0.083466  0.015346  0.110769  0.011464
# USCD  0.005870  -0.326441  0.004418  0.628650  0.012137
# USCS  0.019061   0.404263  0.015175  0.110988  0.011959
# USAD -0.028753  -0.138693 -0.035708  0.077814  0.016298
# USRT -0.001939  -0.682163 -0.001520  0.917965  0.018826
# USTS  0.011238   0.117776  0.015410  0.755734  0.036102
# USBC -0.035472   0.310035 -0.031307  0.123640  0.023031

# %%
#means=100*alpha_stats.groupby([pd.qcut(alpha_stats.Alpha,3)],observed=False)[RETURN_COLS].mean()
means = qcutStats(alpha_stats,'Alpha',4, RETURN_COLS)
means
# Out:
#                               Return_1bd           Return_2bd            \
#                                      avg      stde        avg      stde
# Alpha
# (-24.487000000000002, -1.309]   0.039139  0.014913   0.149174  0.030534
# (-1.309, 0.202]                 0.022593  0.011491   0.123531  0.015281
# (0.202, 1.656]                  0.033915  0.010998   0.141294  0.014713
# (1.656, 28.439]                 0.052538  0.012418   0.187964  0.016320
#
#                               Return_3bd           Return_4bd            \
#                                      avg      stde        avg      stde
# Alpha
# (-24.487000000000002, -1.309]   0.177888  0.034048   0.324216  0.036991
# (-1.309, 0.202]                 0.098644  0.019436   0.248431  0.021616
# (0.202, 1.656]                  0.149211  0.018843   0.272999  0.020961
# (1.656, 28.439]                 0.212573  0.021154   0.350167  0.023863
#
#                               Return_1wk           Return_2wk            \
#                                      avg      stde        avg      stde
# Alpha
# (-24.487000000000002, -1.309]   0.331621  0.040522   0.576801  0.055834
# (-1.309, 0.202]                 0.227123  0.024645   0.425390  0.034006
# (0.202, 1.656]                  0.254395  0.024017   0.490957  0.033085
# (1.656, 28.439]                 0.295323  0.027318   0.560813  0.036343
#
#                               Return_3wk           Return_4wk
#                                      avg      stde        avg      stde
# Alpha
# (-24.487000000000002, -1.309]   0.862457  0.068596   1.158623  0.079872
# (-1.309, 0.202]                 0.661582  0.041483   0.900015  0.047692
# (0.202, 1.656]                  0.701535  0.040677   0.917285  0.046744
# (1.656, 28.439]                 0.852793  0.044562   1.134261  0.051061

# %%
def long_short(long_cutoff=0, short_cutoff=0):
    def x(group):
        return group[group.Alpha>long_cutoff][RETURN_COLS].mean().fillna(0) - \
            group[group.Alpha<short_cutoff][RETURN_COLS].mean().fillna(0)
    return x

# %%
alpha_stats.head()
# Out:
#                                     Name     Alpha  Return_1bd  Return_2bd  \
# cusip
# 00105510                   AFLAC INC COM  2.043253    0.216462    0.512630
# 00365410                 ABIOMED INC COM  0.436040    2.710640    4.487493
# 00790310  ADVANCED MICRO DEVICES INC COM -3.158071    6.809340   12.354091
# 00825210   AFFILIATED MANAGERS GROUP COM  2.942077   -1.076740   -1.524980
# 00846U10    AGILENT TECHNOLOGIES INC COM -2.131617    0.940726    3.509042
#
#           Return_3bd  Return_4bd  Return_5bd  Return_1wk  Return_2wk  \
# cusip
# 00105510    1.549317    2.221443    2.483472    0.512630    3.372061
# 00365410    6.317706    7.955828   10.879898    4.487493   11.061321
# 00790310   17.898832   15.564200   19.455258   12.354091   16.342411
# 00825210   -3.269189   -2.816068   -2.299640   -1.524980   -3.347140
# 00846U10    2.732565    4.375023    4.599026    3.509042    5.704000
#
#           Return_3wk  Return_4wk ForecastDate PrimFactorCode  \
# cusip
# 00105510    0.045567    0.740461   2017-12-27           USIS
# 00365410   19.593414   24.299626   2017-12-27           USHE
# 00790310   18.482480   23.638129   2017-12-27           USHT
# 00825210    1.183926    3.020695   2017-12-27           USCM
# 00846U10    7.600356    9.870051   2017-12-27           USHE
#
#                  PrimFactorName
# cusip
# 00105510              Insurance
# 00365410            Health Care
# 00790310  Hardware & Technology
# 00825210        Capital Markets
# 00846U10            Health Care

# %%
#Simple L/S strategy - equal weight long/short alphas equally
avgPctReturns = alpha_stats.groupby('ForecastDate').apply(long_short(0,0),include_groups=False).reset_index()\
    .sort_values('ForecastDate').set_index('ForecastDate')     
(1+.01*avgPctReturns).cumprod().plot()
print((1+.01*avgPctReturns).cumprod().loc[avgPctReturns.index.max()])
# Out:
# Return_1bd    1.039974
# Return_2bd    1.091831
# Return_3bd    1.088620
# Return_4bd    1.062288
# Return_1wk    0.957722
# Return_2wk    0.943674
# Return_3wk    0.908245
# Return_4wk    0.844311
# Name: 2024-07-24 00:00:00, dtype: float64

# %%
ls_sector = alpha_stats.groupby(['ForecastDate','PrimFactorCode']).apply(long_short(),include_groups=False).reset_index()
pivot_df = ls_sector.pivot(index='ForecastDate', columns='PrimFactorCode', values='Return_1wk').fillna(0)
pivot_df = 1+.01*pivot_df
pivot_df
#(1+ls_sector[ls_sector.PrimFactorCode=='USTS']['Return_1wk']/100.).cumprod()
pivot_df.cumprod().plot(figsize=(12, 6))
print(pivot_df.cumprod().loc[pivot_df.index.max()])
# Out:
# PrimFactorCode
# USAD    0.406108
# USBC    0.751291
# USBK   -0.291178
# USBT    0.860802
# USCD    1.269342
# USCM    1.010646
# USCS    1.404578
# USDF    2.251611
# USEE    0.748404
# USHE    1.028198
# USHT    0.670010
# USID    1.267810
# USIS    1.076776
# USIT    0.769337
# USMT    0.916470
# USRE    0.877586
# USRT    1.044047
# USTR    0.687704
# USTS    0.750425
# USUT    1.401400
# Name: 2024-07-24 00:00:00, dtype: float64

# %%
from datetime import date
pivot_df['USBK'].index[304]
sus = pd.to_datetime(date(2023,10,25))
pivot_df.loc[sus]
susbk = alpha_stats[(alpha_stats.ForecastDate==sus) & (alpha_stats.PrimFactorCode == 'USBK') ]
csv_download_link(susbk,True)
# Out:
# (17, 14)

# %%
usbk = alpha_stats[alpha_stats.PrimFactorCode=='USBK'].groupby('ForecastDate').apply(long_short(0,0),include_groups=False).reset_index()\
    .sort_values('ForecastDate').set_index('ForecastDate')   
(1+.01*usis).cumprod().plot()
# Out:
# <Axes: xlabel='ForecastDate'>
