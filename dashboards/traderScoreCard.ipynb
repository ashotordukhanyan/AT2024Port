# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

module_path = os.path.abspath('..',)
if module_path not in sys.path:
    print(f'Adding {module_path} to PYTHONPATH')
    sys.path.insert(0, module_path)
# Out:
# Adding C:\Users\orduk\PycharmProjects\AT2024Port to PYTHONPATH

# %%
from dashboards.scoresheet import buildStatSheet

# %%
Trader = 'OldSchool'
portDf,dailyReturns = buildStatSheet(Trader,'../trading/stats')

# %%
dailyReturns.sort_values('Date',inplace=True)
dailyReturns.set_index('Date').cumsum().plot()
# Out:
# <Axes: xlabel='Date'>
